# %% [markdown]
# #Practica 3: Simular los tiempos de servicio o inactividad en una fábrica de chips.

# %% [markdown]
# ##Método de la transformada inversa:
#
# Este método transforma números aleatorios uniformes (0,1) en variables de una distribución específica.
#
# ##Distribución Lognormal:
#
# Se utiliza principalmente para modelar tiempos de servicio o inactividad con asimetría positiva. Los valores son siempre positivos y tienden a distribuirse asimétricamente con una "cola" hacia la derecha, usada cuando los tiempos de servicio tienen gran variabilidad.
#
# ##Ejemplo de Aplicación:
#
# En una fábrica de chips, los tiempos de inactividad de brazos automatizados pueden seguir una distribución lognormal, permitiendo simular estos tiempos y planificar mantenimientos preventivos.
#
# ##Pasos para aplicar el método:
#
# Generar un número aleatorio
# 𝑈
# ∼
# (
# 0
# ,
# 1
# )
# .
#
# Aplicar la transformada inversa usando la inversa de la función de distribución acumulada estándar normal para obtener la variable aleatoria lognormal.

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

mu = 1.0
sigma = 0.5
n = 100


U = np.random.uniform(0, 1, n)

Z = mu + sigma * stats.norm.ppf(U)
T = np.exp(Z)

print("Tiempos de inactividad generados:", T)

plt.hist(T, bins=20, edgecolor='black', density=True)

x = np.linspace(min(T), max(T), 100)
pdf = stats.lognorm.pdf(x, sigma, scale=np.exp(mu))
plt.plot(x, pdf, 'r', label='Distribución lognormal teórica')

plt.title("Histograma de los tiempos de inactividad (Distribución Lognormal)")
plt.xlabel("Tiempo de inactividad")
plt.ylabel("Densidad de probabilidad")
plt.legend()
plt.show()
# Out:
# Tiempos de inactividad generados: [3.75204569 2.2103311  2.08439083 1.81417293 2.16029865 1.19971655
#  1.23715051 2.03207277 1.56616995 3.04605597 3.22761219 2.22879493
#  3.14882785 4.16014199 4.76884856 1.59026798 6.69787344 2.86625233
#  2.64688041 2.10726925 2.51819817 3.48139375 1.66467222 3.19104342
#  1.50115884 3.52244868 2.18617607 5.52777352 2.31189771 4.6198097
#  3.79739881 2.79707891 2.7819533  1.35960141 3.21097247 3.42000856
#  2.91924868 2.51685527 1.35547165 1.51920477 2.95227627 2.84647523
#  5.28909733 2.03688009 6.84346249 2.00248229 5.73880544 2.37612515
#  2.83318847 4.30724033 1.6871334  2.6562792  2.87340686 4.81453577
#  2.0863233  3.75565446 2.20003872 1.74460708 1.67545961 3.55858016
#  2.02261613 2.86444935 1.90374699 0.66505938 3.64464423 1.80097211
#  3.61308169 3.03504366 1.93621154 2.00556258 4.05587082 6.85830992
#  2.58496724 2.21852618 6.68960535 2.51982116 4.60318609 5.89703898
#  2.59332654 1.36666126 3.21307725 2.01871224 5.02031257 2.45027226
#  2.82301513 2.15854223 5.54439572 1.40069911 2.17395456 2.71485116
#  2.58544015 2.84471592 2.25487276 1.46670413 2.01834303 3.32975258
#  4.40959179 3.47779384 1.716513   1.24733525]

# %% [markdown]
# #Conclusión
#
# El código permite simular tiempos de servicio o inactividad en una fábrica de chips utilizando la técnica de la transformada inversa y la distribución lognormal. Este método es útil para modelar tiempos de inactividad que suelen ser cortos, pero que ocasionalmente pueden ser mucho más largos debido a problemas complejos. Con esta simulación, se puede:
#
# Predecir y analizar la frecuencia y duración de las interrupciones en los brazos automatizados de la línea de producción.
# Optimizar la planificación de mantenimientos preventivos y correctivos, minimizando el impacto en la producción.
# Mejorar la eficiencia general del sistema, anticipando tiempos de inactividad y ajustando los recursos según sea necesario.
# Este tipo de modelado es crucial para la gestión y optimización de procesos industriales, contribuyendo a un funcionamiento más fluido y eficiente de la fábrica de chips. Es un claro ejemplo de cómo la programación puede influir directamente en la operación de sistemas complejos.
